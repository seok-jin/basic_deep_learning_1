# %%
pip install pykrx
# Out:
# ...
#      ---------------------------------------- 0.0/62.4 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/62.4 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 62.4/62.4 kB 668.1 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/43.1 kB ? eta -:--:--
#      ---------------------------------------- 43.1/43.1 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      ---------------------------------------- 162.3/162.3 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------------------------- ------------- 1.4/2.2 MB 30.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 28.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/52.5 kB ? eta -:--:--
# ...

# %%
x = 10 
print(x)
# Out:
# 10
